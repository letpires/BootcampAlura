# %% [markdown]
# <a href="https://colab.research.google.com/github/letpires/bootcamp_alura/blob/main/notebook1_previsao_uti_covid19_hospital_sirio_libanes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MÓDULO 05**: Tratamento, análise e Machine learning aplicado

# %%
import pandas as pd


dados = pd.read_excel("https://github.com/letpires/bootcamp_alura/blob/main/modulo_final/Kaggle_Sirio_Libanes_ICU_Prediction.xlsx?raw=true")
dados.head()
# Out:
#    PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...    WINDOW  ICU
# 0                         0            1  ...       0-2    0
# 1                         0            1  ...       2-4    0
# 2                         0            1  ...       4-6    0
# 3                         0            1  ...      6-12    0
# 4                         0            1  ...  ABOVE_12    1
#
# [5 rows x 231 columns]

# %%
dados.describe()
# Out:
#        PATIENT_VISIT_IDENTIFIER  ...          ICU
# count               1925.000000  ...  1925.000000
# mean                 192.000000  ...     0.267532
# std                  111.168431  ...     0.442787
# min                    0.000000  ...     0.000000
# 25%                   96.000000  ...     0.000000
# 50%                  192.000000  ...     0.000000
# 75%                  288.000000  ...     1.000000
# max                  384.000000  ...     1.000000
#
# [8 rows x 229 columns]

# %%
dados["ICU"].value_counts()
# Out:
# 0    1410
# 1     515
# Name: ICU, dtype: int64

# %%
# O fit() não converte string em float, então precisamos buscar nos dados somente os flutuantes.
# A função describe() mostra somente os flutuantes

x_columns = dados.describe().columns

# O fit não pode ter dados Nan, então é preciso removê-los

dados_limpos = dados.dropna()

# %%
y = dados_limpos["ICU"]
x = dados_limpos[x_columns].drop(["ICU"], axis=1)

# %%
from sklearn.linear_model import LogisticRegression

modelo = LogisticRegression()
modelo.fit(x,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
x.iloc[4]
# Out:
# PATIENT_VISIT_IDENTIFIER           2.000000
# AGE_ABOVE65                        0.000000
# GENDER                             0.000000
# DISEASE GROUPING 1                 0.000000
# DISEASE GROUPING 2                 0.000000
#                                      ...
# BLOODPRESSURE_SISTOLIC_DIFF_REL   -0.343258
# HEART_RATE_DIFF_REL               -0.576744
# RESPIRATORY_RATE_DIFF_REL         -0.695341
# TEMPERATURE_DIFF_REL              -0.505464
# OXYGEN_SATURATION_DIFF_REL        -0.900129
# Name: 14, Length: 228, dtype: float64

# %%
modelo.predict([x.iloc[4]])
# Out:
# array([1])

# %%
y.iloc[4]
# Out:
# 1

# %%
sum(modelo.predict(x) == y)
# Out:
# 497

# %%
sum(modelo.predict(x) != y)
# Out:
# 48

# %%
#Quantidade de acertos divividos pelo número de pacientes que eu testei vai dar a taxa de acerto, o quão correto está, ou acurácia.

accuracy = sum(modelo.predict(x) == y)/len(y) * 100
accuracy
# Out:
# 91.19266055045871

# %%
# 0 repesenta pessoas que vão pra UTI, e 1 que não vai.

y.value_counts()
# Out:
# 0    281
# 1    264
# Name: ICU, dtype: int64

# %%
from sklearn.dummy import DummyClassifier

modelo = DummyClassifier("most_frequent")
modelo.fit(x,y)
sum(modelo.predict(x) ==y) / len(y) *100
# Out:
# 51.559633027522935

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y, modelo.predict(x))
# Out:
# 0.5155963302752293

# %%
import numpy as np

np.random.seed(73246)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, stratify=y)

# %%
print(len(x_train), len(y_train))
print(len(x_test), len(y_test))
# Out:
# 408 408
# 137 137

# %%
modelo = LogisticRegression()
modelo.fit(x_train, y_train)

y_prediction = modelo.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.8248175182481752

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.514706
# 1    0.485294
# Name: ICU, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.518248
# 1    0.481752
# Name: ICU, dtype: float64

# %%
dados_fake = pd.DataFrame([[1, None, 1], [1, 2.5, 2],
                           [2, 3.0, 1], [2, None, 2],
                          [3, None, 1], [3, 1, 2], [3, None, 3],
                          [4,None,1],[4,6,2], [4,None,3],[4,5,4], [4,None,5]], columns=["usuario", "medida", "janela"])
dados_fake
# Out:
#     usuario  medida  janela
# 0         1     NaN       1
# 1         1     2.5       2
# 2         2     3.0       1
# 3         2     NaN       2
# 4         3     NaN       1
# 5         3     1.0       2
# 6         3     NaN       3
# 7         4     NaN       1
# 8         4     6.0       2
# 9         4     NaN       3
# 10        4     5.0       4
# 11        4     NaN       5

# %%
dados_fake.groupby("usuario", as_index=False)['medida'].fillna(method="ffill").fillna(method="bfill")
# Out:
#     medida
# 0      2.5
# 1      2.5
# 2      3.0
# 3      3.0
# 4      1.0
# 5      1.0
# 6      1.0
# 7      6.0
# 8      6.0
# 9      6.0
# 10     5.0
# 11     5.0

# %%
x_columns = dados.columns

# %%
# features_categoricas são as que tem 0 e 1
#:, representa todas as linhas

def preenche_tabela(dados):
    features_continuas_colunas = dados.iloc[:,13:-2].columns
    features_continuas = dados.groupby("PATIENT_VISIT_IDENTIFIER", as_index=False)[features_continuas_colunas].fillna(method='bfill').fillna(method='ffill')
    features_categoricas = dados.iloc[:, :13]
    
    # a saída é o UTI e janela
    saida = dados.iloc[:, -2:]
    dados_finais = pd.concat([features_categoricas, features_continuas, saida], ignore_index=True, axis=1)
    dados_finais.columns = dados.columns
    return dados_finais

# %%
dados_limpos = preenche_tabela(dados)
dados_limpos.head()
# Out:
#    PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...    WINDOW  ICU
# 0                         0            1  ...       0-2    0
# 1                         0            1  ...       2-4    0
# 2                         0            1  ...       4-6    0
# 3                         0            1  ...      6-12    0
# 4                         0            1  ...  ABOVE_12    1
#
# [5 rows x 231 columns]

# %%
dados_limpos.describe()
# Out:
#        PATIENT_VISIT_IDENTIFIER  ...          ICU
# count               1925.000000  ...  1925.000000
# mean                 192.000000  ...     0.267532
# std                  111.168431  ...     0.442787
# min                    0.000000  ...     0.000000
# 25%                   96.000000  ...     0.000000
# 50%                  192.000000  ...     0.000000
# 75%                  288.000000  ...     1.000000
# max                  384.000000  ...     1.000000
#
# [8 rows x 229 columns]

# %%
dados_limpos = dados_limpos.dropna()
dados_limpos
# Out:
#       PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...    WINDOW  ICU
# 0                            0            1  ...       0-2    0
# 1                            0            1  ...       2-4    0
# 2                            0            1  ...       4-6    0
# 3                            0            1  ...      6-12    0
# 4                            0            1  ...  ABOVE_12    1
# ...                        ...          ...  ...       ...  ...
# 1920                       384            0  ...       0-2    0
# 1921                       384            0  ...       2-4    0
# 1922                       384            0  ...       4-6    0
# 1923                       384            0  ...      6-12    0
# 1924                       384            0  ...  ABOVE_12    0
#
# [1920 rows x 231 columns]

# %%
a_remover = dados_limpos.query("WINDOW=='0-2' and ICU==1")['PATIENT_VISIT_IDENTIFIER'].values
dados_limpos = dados_limpos.query("PATIENT_VISIT_IDENTIFIER not in @a_remover ")
dados_limpos.describe()
# Out:
#        PATIENT_VISIT_IDENTIFIER  ...          ICU
# count               1760.000000  ...  1760.000000
# mean                 192.818182  ...     0.201705
# std                  110.637724  ...     0.401387
# min                    0.000000  ...     0.000000
# 25%                   97.750000  ...     0.000000
# 50%                  191.500000  ...     0.000000
# 75%                  289.250000  ...     0.000000
# max                  384.000000  ...     1.000000
#
# [8 rows x 229 columns]

# %%
def prepare_window(rows):
    if (np.any(rows["ICU"])):
        rows.loc[rows["WINDOW"]=="0-2", "ICU"] = 1
    return rows.loc[rows["WINDOW"] =="0-2"]
    
dados_limpos = dados_limpos.groupby("PATIENT_VISIT_IDENTIFIER").apply(prepare_window)
dados_limpos.AGE_PERCENTIL = dados_limpos.AGE_PERCENTIL.astype("category").cat.codes
dados_limpos.head()
# Out:
#                              PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...  WINDOW  ICU
# PATIENT_VISIT_IDENTIFIER                                            ...
# 0                        0                          0            1  ...     0-2    1
# 2                        10                         2            0  ...     0-2    1
# 3                        15                         3            0  ...     0-2    0
# 4                        20                         4            0  ...     0-2    0
# 5                        25                         5            0  ...     0-2    0
#
# [5 rows x 231 columns]

# %%
dados_limpos
# Out:
#                                PATIENT_VISIT_IDENTIFIER  ...  ICU
# PATIENT_VISIT_IDENTIFIER                                 ...
# 0                        0                            0  ...    1
# 2                        10                           2  ...    1
# 3                        15                           3  ...    0
# 4                        20                           4  ...    0
# 5                        25                           5  ...    0
# ...                                                 ...  ...  ...
# 380                      1900                       380  ...    1
# 381                      1905                       381  ...    0
# 382                      1910                       382  ...    1
# 383                      1915                       383  ...    0
# 384                      1920                       384  ...    0
#
# [352 rows x 231 columns]

# %%
y = dados_limpos["ICU"]
x = dados_limpos[x_columns].drop(["ICU"], axis=1)

dados_limpos = dados_limpos.drop(columns=['WINDOW'])
dados_limpos.head()
# Out:
#                              PATIENT_VISIT_IDENTIFIER  ...  ICU
# PATIENT_VISIT_IDENTIFIER                               ...
# 0                        0                          0  ...    1
# 2                        10                         2  ...    1
# 3                        15                         3  ...    0
# 4                        20                         4  ...    0
# 5                        25                         5  ...    0
#
# [5 rows x 230 columns]

# %%
np.random.seed(73246)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y)

# %%
modelo = DummyClassifier()
modelo.fit(x_train, y_train)

y_prediction = modelo.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/dummy.py:132: FutureWarning: The default value of strategy will change from stratified to prior in 0.24.
#   "stratified to prior in 0.24.", FutureWarning)
# 0.48863636363636365

# %% [markdown]
# ##  **Desafio 01**: pesquisar aprendizado supervisionado, não supervisionado, por reforço e mais (forma).

# %% [markdown]
# ### Aprendizado de máquina é o ramo da inteligência artificial baseado na ideia de que sistemas podem aprender com dados, identificar padrões e tomar decisões com o mínimo de intervenção humana.
#
# *Supervisionado:* quando tem os rótulos dos dados bem estabelecidos. Ex: classificação de imagens (já tem várias imagens de flores previamente catalogadas).
#
# *Não supervisionado:* não tem informações prévias. Ex: separa as flores por similaridade dos dados.

# %%
modelo = LogisticRegression(max_iter=100000)
modelo.fit(x_train, y_train)

y_prediction = modelo.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-159-e8c55ebdea29> in <module>()
#       1 modelo = LogisticRegression(max_iter=100000)
# ----> 2 modelo.fit(x_train, y_train)
#       3
#       4 y_prediction = modelo.predict(x_test)
#       5 accuracy_score(y_test, y_prediction)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1525
#    1526         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1527                          accept_large_sparse=solver != 'liblinear')
#    1528         check_classification_targets(y)
#    1529         self.classes_ = np.unique(y)
#
# ...

# %% [markdown]
# ##  **Desafio 02**: pesquisar sobre regressão, classificação e outros problemas que podem ser solucionados com Machine Learning.

# %% [markdown]
# *Regressão:* quando vamos tentar prever um dado numérico.
#
# *Classificação:* quando queremos encontrar classes. Ex: a raça de tal cachorro pertence a classe A ou B?|

# %% [markdown]
# ## **Desafio 03:** pesquisar sobre ética em DS e inteligência artificial.

# %% [markdown]
# https://medium.com/data-hackers/o-que-%C3%A9-a-privacidade-diferencial-e-qual-a-rela%C3%A7%C3%A3o-com-seguran%C3%A7a-em-machine-learning-bcba0d72eba6

# %% [markdown]
# ##  **Desafio 04:** qual motivo de jogar fora o ICU do dado X? O que acontece se estiver no x? Por que seria bom/ruim?

# %% [markdown]
# ## **Desafio 05**: Decida quanto você vai escolher para treino e quanto para teste? Quanto as pessoas utilizam e qual o motivo?

# %% [markdown]
# É comum utilizar 80% para treino e 20% para teste ou 70% para treino e 30% para teste com um número menor de dados, e caso tenha muitos dados (100 mil por exemplo) dá pra utilizar 90% para treino e 10% para teste.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#
# https://bootcamps.alura.com.br/revisao-das-monitorias-r264
#
# https://youtu.be/ejpUrugr-M0?t=3547 (o Thiago comentou sobre esse assunto na live de monitoria)

# %% [markdown]
# ##  Desafio 06: olhe a documentação da LogisticRegression... o que tem de parâmetro em comum com o train_test_split? O que isso significa pra nós?

# %% [markdown]
# O parâmetro random_state é comum em ambos, sugerindo que o LogisticRegression tambem sofrera influencia da sementre, SEED,  que definimos no `np.random.seed(73246)`
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %% [markdown]
# ##  **Desafio 07**: não usar backfill da janela após a pessoa ter ido pra UTI

# %% [markdown]
# A função preenche_tabela agora não vai mais preencher com os dados do paciente na UTI.

# %%
dados = pd.read_excel("https://github.com/letpires/bootcamp_alura/blob/main/modulo_final/Kaggle_Sirio_Libanes_ICU_Prediction.xlsx?raw=true")
dados.head()

# %%
def preenche_tabela(dados):
    def preenche_na(rows):
        rows.loc[rows["ICU"] != 1] = rows.loc[rows["ICU"] != 1].fillna(method='bfill').fillna(method='ffill')
        return rows
    
    features_continuas_colunas = dados.iloc[:, 13:-2].columns
    features_continuas = dados.groupby("PATIENT_VISIT_IDENTIFIER", as_index=False)[list(features_continuas_colunas) + ["ICU"]].apply(preenche_na)
    features_continuas.drop("ICU", axis=1, inplace=True)
    
    features_categoricas = dados.iloc[:, :13]
    saida = dados.iloc[:, -2:]
    
    dados_finais = pd.concat([features_categoricas, features_continuas, saida], ignore_index=True, axis=1)
    dados_finais.columns = dados.columns
    
    return dados_finais

# %%
dados_limpos2 = preenche_tabela(dados)
dados_limpos2.head()

# %%
dados_limpos2 = dados_limpos2.dropna()

# %%
a_remover = dados_limpos2.query("WINDOW=='0-2' and ICU==1")['PATIENT_VISIT_IDENTIFIER'].values
dados_limpos2 = dados_limpos2.query("PATIENT_VISIT_IDENTIFIER not in @a_remover")
dados_limpos2.describe()

# %%
def prepare_window(rows):
    if(np.any(rows["ICU"])):
        rows.loc[rows["WINDOW"]=="0-2", "ICU"] = 1
    return rows.loc[rows["WINDOW"] == "0-2"]

dados_limpos2 = dados_limpos2.groupby("PATIENT_VISIT_IDENTIFIER").apply(prepare_window)
dados_limpos2.head()

# %%
dados_limpos.shape

# %%
dados_limpos2.shape

# %% [markdown]
# ##  **Desafio 08:** Arranque fora as colunas que não devem ser utilizadas.

# %%
dados_limpos.head()

# %%
dados_limpos.drop(['PATIENT_VISIT_IDENTIFIER', 'WINDOW'], axis=1, inplace=True)
dados_limpos.head()

# %% [markdown]
# É necessario um estudo para definir quais colunas fazem sentido, mas podemos tirar com certeza a PATIENT_VISIT_IDENTIFIER e WINDOW, montei a função filtra_colunas_por_sufixo para facilitar os testes para definir se faz sentido manter todas as colunas com mediana, media, minimo, max e diff.
#
# Outro estudo que é necessario é se todas as colunas tem impacto em o paciente ir ou não para a UTI.

# %%
# Quando definimos o x_columns utilizamos o parâmetro describe pra pegar as 
# colunas, no entanto, essa função não pega strings. Pra isso, vamos analisar 
# inicialmente qual coluna não está no x_columns e verificar se é importante.

for coluna in dados.columns:
  if coluna not in x_columns:
    print(coluna)

# %%
dados_limpos = dados_limpos.drop(columns=['WINDOW'])
dados_limpos.head()

# %%
dados_limpos.AGE_PERCENTIL.value_counts()

# %%
from sklearn.tree import DecisionTreeClassifier

modelo_arvore = DecisionTreeClassifier
modelo_arvore.fit(x_train, y_train)
predicao_arvore = modelo_arvore.predict(x_test)
accuracy_score(y_test, predicao_arvore)
